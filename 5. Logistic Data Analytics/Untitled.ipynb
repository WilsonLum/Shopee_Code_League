# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dataset/delivery_orders_march.csv')
df
# Out:
#                 orderid        pick  1st_deliver_attempt  2nd_deliver_attempt  \
# 0            2215676524  1583138397         1.583385e+09                  NaN
# 1            2219624609  1583309968         1.583463e+09         1.583799e+09
# 2            2220979489  1583306434         1.583460e+09                  NaN
# 3            2221066352  1583419016         1.583556e+09                  NaN
# 4            2222478803  1583318305         1.583480e+09                  NaN
# 5            2222597288  1583328320         1.583567e+09                  NaN
# 6            2222738456  1583148712         1.583386e+09         1.583714e+09
# 7            2224695304  1583127841         1.583837e+09                  NaN
# 8            2224704587  1583307779         1.583389e+09         1.583712e+09
# 9            2225138267  1583336611         1.583814e+09                  NaN
# 10           2225861241  1583575053         1.583817e+09                  NaN
# ...

# %%
import datetime
timestamp = datetime.datetime.fromtimestamp(1500000000)
timestamp
# Out:
# datetime.datetime(2017, 7, 14, 10, 40)

# %%
df['pick'] = df['pick'].astype(int)
df
# Out:
#                 orderid        pick  1st_deliver_attempt  2nd_deliver_attempt  \
# 0            2215676524  1583138397         1.583385e+09                  NaN
# 1            2219624609  1583309968         1.583463e+09         1.583799e+09
# 2            2220979489  1583306434         1.583460e+09                  NaN
# 3            2221066352  1583419016         1.583556e+09                  NaN
# 4            2222478803  1583318305         1.583480e+09                  NaN
# 5            2222597288  1583328320         1.583567e+09                  NaN
# 6            2222738456  1583148712         1.583386e+09         1.583714e+09
# 7            2224695304  1583127841         1.583837e+09                  NaN
# 8            2224704587  1583307779         1.583389e+09         1.583712e+09
# 9            2225138267  1583336611         1.583814e+09                  NaN
# 10           2225861241  1583575053         1.583817e+09                  NaN
# ...

# %%
df.dtypes
# Out:
# orderid                  int64
# pick                     int32
# 1st_deliver_attempt    float64
# 2nd_deliver_attempt    float64
# buyeraddress            object
# selleraddress           object
# dtype: object

# %%
df['pick_date'] = df['pick'].dt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2373ac713f8f> in <module>
# ----> 1 df['pick_date'] = df['pick'].dt
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...

# %%
text = np.busyday_count('2019-01-21','2020-03-28',weekmask=[1,1,1,1,1,1,0],holidays=['2020-03-08','2020-03-25','2020-03-30','2020-03-31'])
text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bdfc67571e7e> in <module>
# ----> 1 text = np.busyday_count('2019-01-21','2020-03-28',weekmask=[1,1,1,1,1,1,0],holidays=['2020-03-08','2020-03-25','2020-03-30','2020-03-31'])
#       2 text
#
# AttributeError: module 'numpy' has no attribute 'busyday_count'
